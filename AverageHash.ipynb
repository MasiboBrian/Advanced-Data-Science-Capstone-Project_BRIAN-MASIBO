# %% [markdown]
# <a href="https://colab.research.google.com/github/MasiboBrian/AirBNB-Price-Prediction/blob/master/AverageHash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import dependencies
# !pip install imagehash
from PIL import Image
import imagehash

# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/1_1.jpg'))
print('Picture 1_1 : ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/1_2.jpg'))
print('Picture 1_2 : ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))

# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/2_1.jpg'))
print('Picture 2_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/2_2.jpg'))
print('Picture 2_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))

# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/3_1.jpg'))
print('Picture 3_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/3_2.jpg'))
print('Picture 3_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/4_1.jpg'))
print('Picture 4_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/4_2.jpg'))
print('Picture 4_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/5_1.jpg'))
print('Picture 5_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/5_2.jpg'))
print('Picture 5_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))

# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/6_1.jpg'))
print('Picture 6_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/6_2.jpg'))
print('Picture 6_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/7_1.jpg'))
print('Picture 7_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/7_2.jpg'))
print('Picture 7_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/8_1.jpg'))
print('Picture 8_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/8_2.jpg'))
print('Picture 8_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Create the Hash Object of the first image
image1 = imagehash.average_hash(Image.open('all/9_1.jpg'))
print('Picture 9_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/9_2.jpg'))
print('Picture 9_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))

# Create the Hash Object of the first image

image1 = imagehash.average_hash(Image.open('all/10_1.jpg'))
print('Picture 10_1: ' + str(image1))

# Create the Hash Object of the second image
image2 = imagehash.average_hash(Image.open('all/10_2.jpg'))
print('Picture 10_2: ' + str(image2))

# Compare hashes to determine whether the pictures are the same or not
if(image1 == image2):
    print("The images in this pair are identical")
else:
    print("The images in this pair are different, distance: " + str(image1 - image2))
# Out:
# ...
#      |████████████████████████████████| 296kB 3.9MB/s
# ...
# Picture 1_1 : 0000007c3c000000
# Picture 1_2 : c707003c3c000000
# The images in this pair are different, distance: 9
# Picture 2_1: 0000007c3c000000
# Picture 2_2: c707003c3c000000
# The images in this pair are different, distance: 9
# Picture 3_1: ffff8fcffefeff00
# Picture 3_2: ffff87cfffffffff
# The images in this pair are different, distance: 11
# Picture 4_1: ffffc3cfc3c3ffff
# Picture 4_2: ffffc3cfc3c3ffff
# The images in this pair are identical
# Picture 5_1: ffffff83813f1f3f
# Picture 5_2: ffffff83813f1f7f
# The images in this pair are different, distance: 1
# Picture 6_1: ffffff83817f3f3f
# Picture 6_2: ffffff83817f3f7f
# The images in this pair are different, distance: 1
# Picture 7_1: ffe7e7e7e7e7c3e7
# Picture 7_2: ffe7e7e7e7e7c3e7
# The images in this pair are identical
# Picture 8_1: ffffc3cfc3c3ffff
# Picture 8_2: ffffd3cfc3c3ffff
# The images in this pair are different, distance: 1
# ...
